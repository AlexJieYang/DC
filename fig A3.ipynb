# %%
import random
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import math
import re
from collections import Counter
import scipy.stats
import seaborn as sns

# %%
path11 = r'E:\netData\MAGzip\MAG Nobel\2 Nobelpapers\712 NobelpapersCD.zip'
path12 = r'E:\netData\MAGzip\MAG Nobel\2 Nobelpapers\712 Nobelpapers.zip'
path21 = r'E:\netData\MAGzip\MAG Nobel\2 NobelpaperControls\20954 NobelpapercontrolsCD.zip'
path22 = r'E:\netData\MAGzip\MAG Nobel\2 NobelpaperControls\20954 Nobelpapercontrols.zip'

# %%
fNobel1 = pd.read_csv(path11)
fControl1 = pd.read_csv(path21)
fNobel2 = pd.read_csv(path12)
fControl2 = pd.read_csv(path22)

# %%
fNobel = pd.concat([fNobel1 , fNobel2] , axis = 1)
fControl = pd.concat([fControl1 , fControl2] , axis = 1)

fNobel = fNobel.loc[:, ~fNobel.columns.duplicated()]
fControl = fControl.loc[:, ~fControl.columns.duplicated()]

# %%
fNobel['type']='Nobel-winning papers'
fControl['type']='Control group papers'

# %% [markdown]
# # FIG

# %%
f, ax = plt.subplots(figsize=(7, 7))
sns.kdeplot(data=fControl, x="ni", multiple="stack",palette="crest",label='Control papers')
sns.kdeplot(data=fNobel, x="ni", multiple="stack",palette="plasma",label='Nobel papers')
#ax.set_xscale("log")
ax.set_yscale("log")
plt.ylim((10e-6,10e-1))
plt.xlim((0,5000))
plt.xticks(size = 25)
plt.yticks([10e-2,10e-3,10e-4,10e-5,10e-6],size = 25)
plt.legend(fontsize = 30)
plt.xlabel(r'Disruptive Citation',fontsize = 30)
plt.ylabel(r'Density',fontsize = 30)
plt.savefig(r"G:\A J YANG PAPER\MAG analysis\papers Nobel\QSS Disruptive citation for Nobel Prize papers\fig\fig A3\a1.pdf",bbox_inches = 'tight')
# Out:
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\98992924.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fControl, x="ni", multiple="stack",palette="crest",label='Control papers')
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\98992924.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fNobel, x="ni", multiple="stack",palette="plasma",label='Nobel papers')

# %%
fNobel1 = fNobel[fNobel['CD']==1]
fControl1 = fControl[fControl['CD']==1]

# %%
f, ax = plt.subplots(figsize=(7,7))
sns.kdeplot(data=fControl1, x="ni", multiple="stack",palette="crest",label='Control papers\nCD-index = 1')
sns.kdeplot(data=fNobel1, x="ni", multiple="stack",palette="plasma",label='Nobel papers\nCD-index = 1')
#ax.set_xscale("log")
ax.set_yscale("log")
plt.ylim((10e-6,10e-1))
plt.xlim((0,5000))
plt.xticks(size = 25)
plt.yticks([10e-1,10e-2,10e-3,10e-4,10e-5,10e-6],size = 25)
plt.legend(fontsize = 30)
plt.xlabel(r'Disruptive Citation',fontsize = 30)
plt.ylabel(r'Density',fontsize = 30)
plt.savefig(r"G:\A J YANG PAPER\MAG analysis\papers Nobel\QSS Disruptive citation for Nobel Prize papers\fig\fig A3\a2.pdf",bbox_inches = 'tight')
# Out:
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\1882655940.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fControl1, x="ni", multiple="stack",palette="crest",label='Control papers\nCD-index = 1')
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\1882655940.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fNobel1, x="ni", multiple="stack",palette="plasma",label='Nobel papers\nCD-index = 1')

# %%
f, ax = plt.subplots(figsize=(7, 7))
sns.kdeplot(data=fControl, x="CD", multiple="stack",palette="crest",label='Control papers')
sns.kdeplot(data=fNobel, x="CD", multiple="stack",palette="plasma",label='Nobel papers')
#ax.set_xscale("log")
#ax.set_yscale("log")
#plt.ylim((10e-6,10e0))
plt.xlim((-1,1))
plt.xticks([-1,-0.5,0,0.5,1],size = 25)
plt.yticks(size = 25)
plt.legend(fontsize = 30)
plt.xlabel(r'CD-index',fontsize = 30)
plt.ylabel(r'Density',fontsize = 30)
plt.savefig(r"G:\A J YANG PAPER\MAG analysis\papers Nobel\QSS Disruptive citation for Nobel Prize papers\fig\fig A3\a3.pdf",bbox_inches = 'tight')
# Out:
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\3718793533.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fControl, x="CD", multiple="stack",palette="crest",label='Control papers')
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\3718793533.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fNobel, x="CD", multiple="stack",palette="plasma",label='Nobel papers')

# %%
f, ax = plt.subplots(figsize=(7, 7))
sns.kdeplot(data=fControl, x="DIsharp", multiple="stack",palette="crest",label='Control papers')
sns.kdeplot(data=fNobel, x="DIsharp", multiple="stack",palette="plasma",label='Nobel papers')
#ax.set_xscale("log")
#ax.set_yscale("log")
#plt.ylim((10e-6,10e0))
plt.xlim((-1,1))
plt.xticks([-1,-0.5,0,0.5,1],size = 25)
plt.yticks(size = 25)
plt.legend(fontsize = 30)
plt.xlabel(r'DI*',fontsize = 30)
plt.ylabel(r'Density',fontsize = 30)
plt.savefig(r"G:\A J YANG PAPER\MAG analysis\papers Nobel\QSS Disruptive citation for Nobel Prize papers\fig\fig A3\a4.pdf",bbox_inches = 'tight')
# Out:
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\3725724723.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fControl, x="DIsharp", multiple="stack",palette="crest",label='Control papers')
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\3725724723.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fNobel, x="DIsharp", multiple="stack",palette="plasma",label='Nobel papers')

# %%
f, ax = plt.subplots(figsize=(7, 7))
sns.kdeplot(data=fControl, x="DIeasy", multiple="stack",palette="crest",label='Control papers')
sns.kdeplot(data=fNobel, x="DIeasy", multiple="stack",palette="plasma",label='Nobel papers')
#ax.set_xscale("log")
#ax.set_yscale("log")
#plt.ylim((10e-6,10e0))
plt.xlim((-1,1))
plt.xticks([-1,-0.5,0,0.5,1],size = 25)
plt.yticks(size = 25)
plt.legend(fontsize = 30)
plt.xlabel(r'simple DI',fontsize = 30)
plt.ylabel(r'Density',fontsize = 30)
plt.savefig(r"G:\A J YANG PAPER\MAG analysis\papers Nobel\QSS Disruptive citation for Nobel Prize papers\fig\fig A3\a5.pdf",bbox_inches = 'tight')
# Out:
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\22812390.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fControl, x="DIeasy", multiple="stack",palette="crest",label='Control papers')
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\22812390.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fNobel, x="DIeasy", multiple="stack",palette="plasma",label='Nobel papers')

# %%
f, ax = plt.subplots(figsize=(7, 7))
sns.kdeplot(data=fControl, x="C-CD P", multiple="stack",palette="crest",label='Control papers')
sns.kdeplot(data=fNobel, x="C-CD P", multiple="stack",palette="plasma",label='Nobel papers')
#ax.set_xscale("log")
#ax.set_yscale("log")
#plt.ylim((10e-6,10e0))
plt.xlim((0,2))
plt.xticks([0,0.5,1,1.5,2],size = 25)
plt.yticks(size = 25)
plt.legend(fontsize = 30)
plt.xlabel(r'C-CD P',fontsize = 30)
plt.ylabel(r'Density',fontsize = 30)
plt.savefig(r"G:\A J YANG PAPER\MAG analysis\papers Nobel\QSS Disruptive citation for Nobel Prize papers\fig\fig A3\a6.pdf",bbox_inches = 'tight')
# Out:
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\249103706.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fControl, x="C-CD P", multiple="stack",palette="crest",label='Control papers')
# C:\Users\nd\AppData\Local\Temp\ipykernel_2612\249103706.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=fNobel, x="C-CD P", multiple="stack",palette="plasma",label='Nobel papers')
